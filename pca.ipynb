# %%
import pandas as pd

# %%
data = pd.read_csv("base_data.csv")

# %%
data
# Out:
#        Emotions                                   Path   actor Gender Source
# 0         angry  E:\datasets\crema\1001_DFA_ANG_XX.wav  1001.0   male  crema
# 1       disgust  E:\datasets\crema\1001_DFA_DIS_XX.wav  1001.0   male  crema
# 2          fear  E:\datasets\crema\1001_DFA_FEA_XX.wav  1001.0   male  crema
# 3         happy  E:\datasets\crema\1001_DFA_HAP_XX.wav  1001.0   male  crema
# 4       neutral  E:\datasets\crema\1001_DFA_NEU_XX.wav  1001.0   male  crema
# ...         ...                                    ...     ...    ...    ...
# 12157  surprise          E:\datasets\savee\KL_su11.wav     NaN   male  savee
# 12158  surprise          E:\datasets\savee\KL_su12.wav     NaN   male  savee
# 12159  surprise          E:\datasets\savee\KL_su13.wav     NaN   male  savee
# 12160  surprise          E:\datasets\savee\KL_su14.wav     NaN   male  savee
# 12161  surprise          E:\datasets\savee\KL_su15.wav     NaN   male  savee
#
# [12162 rows x 5 columns]
